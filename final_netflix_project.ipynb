# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv(r"C:\Users\Sparta laptop\Downloads\netflix_tv_shows_detailed_up_to_2025-selected-columns.csv")

# %%
df.head()
# Out:
#    show_id     type              title director  \
# 0    33238  TV Show        Running Man      안재철
# 1    32415  TV Show              Conan      NaN
# 2    37757  TV Show  MasterChef Greece      NaN
# 3    75685  TV Show         Prostřeno!      NaN
# 4    33847  TV Show           The Talk      NaN
#
#                                                 cast  \
# 0  Yoo Jae-suk, Jee Seok-jin, Kim Jong-kook, Haha...
# 1                        Conan O'Brien, Andy Richter
# 2                                                NaN
# 3                        Václav Vydra, Jana Boušková
# 4  Amanda Kloots, Jerry O'Connell, Akbar Gbaja-Bi...
#
#                              country  date_added  release_year  rating  \
# 0                        South Korea  2010-07-11          2010   8.241
# 1           United States of America  2010-11-08          2010   7.035
# 2                             Greece  2010-10-03          2010   5.600
# ...

# %%
df.tail()
# Out:
#        show_id     type                                   title  \
# 15995   284892  TV Show                              Sammelanam
# 15996   277665  TV Show                            Anne Shirley
# 15997   284972  TV Show                     Le onde del passato
# 15998   284613  TV Show                                 AI히치하이커
# 15999   251815  TV Show  Alex & Laura's Saturday Night Takeaway
#
#                  director                                               cast  \
# 15995                 NaN                                                NaN
# 15996                 NaN  Honoka Inoue, Yasunori Matsumoto, Aya Nakamura...
# 15997  Giulio Manfredonia  Anna Valle, Giorgio Marchesi, Irene Ferri, Fau...
# 15998                 NaN                                                NaN
# 15999                 NaN                       Alex Bickerton, Lauren Blake
#
#       country  date_added  release_year  rating   duration language  \
# ...

# %%
df.shape
# Out:
# (16000, 13)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'language', 'popularity',
#        'vote_count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      5035 non-null   object
#  4   cast          14843 non-null  object
#  5   country       14203 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      16000 non-null  object
#  10  language      16000 non-null  object
#  11  popularity    16000 non-null  float64
#  12  vote_count    16000 non-null  int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 1.6+ MB

# %%
df.dtypes
# Out:
# show_id           int64
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating          float64
# duration         object
# language         object
# popularity      float64
# vote_count        int64
# dtype: object

# %%
df.describe()
# Out:
#              show_id  release_year        rating    popularity    vote_count
# count   16000.000000  16000.000000  16000.000000  16000.000000  16000.000000
# mean   126567.673375   2017.500000      5.417107     64.850984    107.014313
# std     75640.760545      4.609916      3.266492    139.387289    607.461581
# min       767.000000   2010.000000      0.000000      2.323000      0.000000
# 25%     67867.750000   2013.750000      2.700000     24.874750      1.000000
# 50%     94380.500000   2017.500000      6.800000     36.187500      4.000000
# 75%    206920.750000   2021.250000      7.800000     62.187500     30.000000
# max    285345.000000   2025.000000     10.000000   6421.923000  24664.000000

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director        10965
# cast             1157
# country          1797
# date_added          0
# release_year        0
# rating              0
# duration            0
# language            0
# popularity          0
# vote_count          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
df["director"].isnull().sum()
# Out:
# np.int64(10965)

# %%
df["type"].unique()
# Out:
# array(['TV Show'], dtype=object)

# %%
df["rating"].unique()
# Out:
# array([8.241, 7.035, 5.6  , ..., 8.016, 9.667, 6.818], shape=(1184,))

# %%
df["language"].unique()
# Out:
# array(['ko', 'en', 'el', 'cs', 'ru', 'fr', 'da', 'hi', 'ja', 'pt', 'nl',
#        'zh', 'de', 'es', 'tl', 'ar', 'et', 'id', 'sv', 'tr', 'ro', 'cn',
#        'it', 'uk', 'pl', 'fi', 'bg', 'no', 'fa', 'ka', 'kk', 'hy', 'he',
#        'th', 'af', 'ur', 'bn', 'sr', 'ca', 'hr', 'ml', 'lt', 'hu', 'ms',
#        'am', 'lb', 'sk', 'bs', 'as', 'kn', 'cy', 'vi', 'ta', 'gl', 'sl',
#        'is', 'ga', 'nb', 'xx', 'mk', 'te', 'za', 'mr', 'la', 'or', 'pa',
#        'lv', 'zu', 'az', 'km', 'mt'], dtype=object)

# %%
df["type"].value_counts()
# Out:
# type
# TV Show    16000
# Name: count, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# 0.000     3673
# 7.000      773
# 8.000      753
# 6.000      583
# 10.000     471
#           ...
# 6.375        1
# 8.550        1
# 6.662        1
# 6.882        1
# 6.818        1
# Name: count, Length: 1184, dtype: int64

# %%
df["added_year"] = df["date_added"].dt.year

# %%
df["added_month"] = df["date_added"].dt.month

# %%
df["added_month_name"] = df["date_added"].dt.month_name()

# %%
df["release_decade"] = (df["release_year"] // 10) * 10

# %%
df.isnull().sum()
# Out:
# show_id                 0
# type                    0
# title                   0
# director            10965
# cast                 1157
# country              1797
# date_added              0
# release_year            0
# rating                  0
# duration                0
# language                0
# popularity              0
# vote_count              0
# added_year              0
# added_month             0
# added_month_name        0
# release_decade          0
# dtype: int64

# %%
df["director"]=df["director"].fillna("Unknown")

# %%
df["cast"]=df["cast"].fillna("Unknown")

# %%
df["country"]=df["cast"].fillna("country")

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director            0
# cast                0
# country             0
# date_added          0
# release_year        0
# rating              0
# duration            0
# language            0
# popularity          0
# vote_count          0
# added_year          0
# added_month         0
# added_month_name    0
# release_decade      0
# dtype: int64

# %%
df["title"].nunique()
# Out:
# 15668

# %%
df["type"].value_counts()
# Out:
# type
# TV Show    16000
# Name: count, dtype: int64

# %%
df["country"].nunique()
# Out:
# 14629

# %%
df["language"].nunique()
# Out:
# 71

# %%
df["rating"].mean()
# Out:
# np.float64(5.4171070625)

# %%
df["popularity"].mean()
# Out:
# np.float64(64.8509839375)

# %%
df["popularity"].max()
# Out:
# 6421.923

# %%
df.nlargest(10, "rating")[["title", "type", "rating"]]
# Out:
#                              title     type  rating
# 14         Pyaar Kii Ye Ek Kahaani  TV Show    10.0
# 34           Geet Hui Sabse Parayi  TV Show    10.0
# 59                Under the Clouds  TV Show    10.0
# 111                       Distal-4  TV Show    10.0
# 165  Kung Fu Masters of the Zodiac  TV Show    10.0
# 171                   Endless Love  TV Show    10.0
# 209                AI Football GGO  TV Show    10.0
# 212            Arashi ni Shiyagare  TV Show    10.0
# 236                  The Outlander  TV Show    10.0
# 242                 This is Хорошо  TV Show    10.0

# %%
df.nlargest(10, "popularity")[["title", "type", "popularity"]]
# Out:
#                                         title     type  popularity
# 5000       The Late Show with Stephen Colbert  TV Show    6421.923
# 4000   The Tonight Show Starring Jimmy Fallon  TV Show    4925.253
# 2000                    Good Mythical Morning  TV Show    3414.466
# 8000                    Chronicles of the Sun  TV Show    2987.485
# 14000                          Volta por Cima  TV Show    2885.720
# 14001                           She's the One  TV Show    2862.872
# 14004                         Crazy About You  TV Show    2442.243
# 14002         La Casa de los Famosos Colombia  TV Show    2398.165
# 4001              Late Night with Seth Meyers  TV Show    2395.016
# 9000                                   GH dúo  TV Show    2379.884

# %%
type_percentage = df["type"].value_counts(normalize=True) * 100
type_percentage
# Out:
# type
# TV Show    100.0
# Name: proportion, dtype: float64

# %%
np.mean(df["release_year"])
# Out:
# np.float64(2017.5)

# %%
np.median(df["release_year"])
# Out:
# np.float64(2017.5)

# %%
np.std(df["popularity"])
# Out:
# 139.38293346486154

# %%
df[["rating", "popularity", "vote_count"]].corr()
# Out:
#               rating  popularity  vote_count
# rating      1.000000    0.052165    0.131719
# popularity  0.052165    1.000000    0.145118
# vote_count  0.131719    0.145118    1.000000

# %%
df["country"].value_counts().head(10)
# Out:
# country
# Unknown                                                         1157
# Qing Zu, Deng Yuting, Ying Liang, Hongyun Liu, Quansheng Gao      10
# David Attenborough                                                 9
# Jörg Pilawa                                                        5
# RM, Jin, Suga, j-hope, Jimin                                       5
# Gordon Ramsay                                                      4
# Michael Portillo                                                   4
# Rylan Clark                                                        4
# RuPaul                                                             4
# Steve Harvey                                                       3
# Name: count, dtype: int64

# %%
top_countries = (
    df[df["country"] != "Unknown"]["country"]
    .value_counts()
    .head(10)
)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title("Top 10 Countries by Number of Titles")
plt.xlabel("Number of Titles")
plt.ylabel("Country")
plt.show()

# %%
df["country"].nunique()
# Out:
# 14629

# %%
df["country"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["country_list"] = df["country"].str.split(", ")

# %%
country_counts = df["country_list"].explode().value_counts()
country_counts.head(10)
# Out:
# country_list
# Unknown             1157
# Kana Hanazawa         72
# Ai Kayano             51
# Yoko Hikasa           48
# Yuichi Nakamura       47
# Natsuki Hanae         45
# Saori Hayami          43
# Takahiro Sakurai      43
# Yuki Kaji             43
# Haruka Tomatsu        42
# Name: count, dtype: int64

# %%
country_counts = df["country_list"].explode().value_counts()
country_counts = country_counts.drop("Unknown", errors="ignore")
country_counts.head(10)
# Out:
# country_list
# Kana Hanazawa       72
# Ai Kayano           51
# Yoko Hikasa         48
# Yuichi Nakamura     47
# Natsuki Hanae       45
# Saori Hayami        43
# Takahiro Sakurai    43
# Yuki Kaji           43
# Haruka Tomatsu      42
# Nao Toyama          40
# Name: count, dtype: int64

# %%
top_countries = country_counts.head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title("Top 10 Countries Producing TV Shows")
plt.xlabel("Number of TV Shows")
plt.ylabel("Country")
plt.show()

# %%
language_counts = df["language"].value_counts()
language_counts.head(10)
# Out:
# language
# en    4437
# zh    2456
# ja    1883
# ko    1364
# es     916
# fr     585
# de     451
# tl     398
# ar     347
# pt     346
# Name: count, dtype: int64

# %%
language_counts = language_counts.drop("Unknown", errors="ignore")

# %%
language_counts.head(10)
# Out:
# language
# en    4437
# zh    2456
# ja    1883
# ko    1364
# es     916
# fr     585
# de     451
# tl     398
# ar     347
# pt     346
# Name: count, dtype: int64

# %%
top_languages = language_counts.head(10)
plt.figure(figsize=(10, 5))
sns.barplot(
    x=top_languages.values,
    y=top_languages.index
)
plt.title("Top 10 Languages by Number of TV Shows")
plt.xlabel("Number of TV Shows")
plt.ylabel("Language")
plt.show()

# %%
language_percentage = (
    language_counts / language_counts.sum()
) * 100

language_percentage.head(10)
# Out:
# language
# en    27.73125
# zh    15.35000
# ja    11.76875
# ko     8.52500
# es     5.72500
# fr     3.65625
# de     2.81875
# tl     2.48750
# ar     2.16875
# pt     2.16250
# Name: count, dtype: float64

# %%
year_counts = df["release_year"].value_counts().sort_index()
year_counts
# Out:
# release_year
# 2010    1000
# 2011    1000
# 2012    1000
# 2013    1000
# 2014    1000
# 2015    1000
# 2016    1000
# 2017    1000
# 2018    1000
# 2019    1000
# 2020    1000
# 2021    1000
# 2022    1000
# 2023    1000
# 2024    1000
# 2025    1000
# Name: count, dtype: int64

# %%
df["release_year"].value_counts().head(10)
# Out:
# release_year
# 2010    1000
# 2011    1000
# 2012    1000
# 2013    1000
# 2014    1000
# 2015    1000
# 2016    1000
# 2017    1000
# 2018    1000
# 2019    1000
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.lineplot(x=year_counts.index, y=year_counts.values)
plt.title("TV Shows Released by Year")
plt.xlabel("Release Year")
plt.ylabel("Number of TV Shows")
plt.show()

# %%
df["release_decade"].value_counts().sort_index()
# Out:
# release_decade
# 2010    10000
# 2020     6000
# Name: count, dtype: int64

# %%
decade_counts = df["release_decade"].value_counts().sort_index()

plt.figure(figsize=(10, 5))

sns.barplot(x=decade_counts.index, y=decade_counts.values)

plt.title("TV Shows by Release Decade")
plt.xlabel("Release Decade")
plt.ylabel("Number of TV Shows")
plt.xticks(rotation=45)

plt.show()

# %%
added_year_counts = df["added_year"].value_counts().sort_index()

added_year_counts
# Out:
# added_year
# 2010    1000
# 2011    1000
# 2012    1000
# 2013    1000
# 2014    1000
# 2015    1000
# 2016    1000
# 2017    1000
# 2018    1000
# 2019    1000
# 2020    1000
# 2021    1000
# 2022    1000
# 2023    1000
# 2024    1000
# 2025    1000
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 5))

sns.lineplot(
    x=added_year_counts.index,
    y=added_year_counts.values
)

plt.title("TV Shows Added to Netflix by Year")
plt.xlabel("Year Added")
plt.ylabel("Number of TV Shows")

plt.show()

# %%
month_counts = df["added_month_name"].value_counts()

month_counts
# Out:
# added_month_name
# January      2167
# October      1692
# September    1600
# April        1585
# March        1446
# February     1405
# July         1297
# November     1062
# June         1012
# August        984
# May           958
# December      792
# Name: count, dtype: int64

# %%
month_counts.head(5)
# Out:
# added_month_name
# January      2167
# October      1692
# September    1600
# April        1585
# March        1446
# Name: count, dtype: int64

# %%
rating_counts = df["rating"].value_counts()
rating_counts
# Out:
# rating
# 0.000     3673
# 7.000      773
# 8.000      753
# 6.000      583
# 10.000     471
#           ...
# 6.375        1
# 8.550        1
# 6.662        1
# 6.882        1
# 6.818        1
# Name: count, Length: 1184, dtype: int64

# %%
rating_counts = rating_counts.drop("Unknown", errors="ignore")
rating_counts
# Out:
# rating
# 0.000     3673
# 7.000      773
# 8.000      753
# 6.000      583
# 10.000     471
#           ...
# 6.375        1
# 8.550        1
# 6.662        1
# 6.882        1
# 6.818        1
# Name: count, Length: 1184, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(
    x=rating_counts.values,
    y=rating_counts.index
)
plt.title("TV Shows by Rating")
plt.xlabel("Number of TV Shows")
plt.ylabel("Rating")
plt.show()

# %%
rating_percentage = (
    rating_counts / rating_counts.sum()
) * 100
rating_percentage.head(10)
# Out:
# rating
# 0.0     22.95625
# 7.0      4.83125
# 8.0      4.70625
# 6.0      3.64375
# 10.0     2.94375
# 7.5      2.57500
# 7.7      2.05625
# 7.2      2.03750
# 7.3      2.01875
# 7.8      1.95625
# Name: count, dtype: float64

# %%
top_popular = df.nlargest(10, "popularity")
top_popular[["title", "popularity", "vote_count"]]
# Out:
#                                         title  popularity  vote_count
# 5000       The Late Show with Stephen Colbert    6421.923         288
# 4000   The Tonight Show Starring Jimmy Fallon    4925.253         321
# 2000                    Good Mythical Morning    3414.466          67
# 8000                    Chronicles of the Sun    2987.485         117
# 14000                          Volta por Cima    2885.720          16
# 14001                           She's the One    2862.872           9
# 14004                         Crazy About You    2442.243          16
# 14002         La Casa de los Famosos Colombia    2398.165          27
# 4001              Late Night with Seth Meyers    2395.016          98
# 9000                                   GH dúo    2379.884           4

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    x="popularity",
    y="title",
    data=top_popular
)
plt.title("Top 10 Most Popular TV Shows")
plt.xlabel("Popularity")
plt.ylabel("TV Show")

plt.show()

# %%
top_votes = df.nlargest(10, "vote_count")
top_votes[["title", "vote_count", "popularity"]]
# Out:
#                   title  vote_count  popularity
# 1001    Game of Thrones       24664     812.157
# 7065        Money Heist       18791     133.640
# 6019    Stranger Things       18075     341.461
# 7      The Walking Dead       16790     485.660
# 11001        Squid Game       15536     836.570
# 6005            Lucifer       14889     495.093
# 7021          Riverdale       13505     283.997
# 7002    The Good Doctor       12498     659.996
# 11084       WandaVision       12125      84.738
# 11043              Loki       11751     126.250

# %%
plt.figure(figsize=(10, 6))
sns.barplot(
    x="vote_count",
    y="title",
    data=top_votes
)
plt.title("Top 10 TV Shows by Vote Count")
plt.xlabel("Vote Count")
plt.ylabel("TV Show")

plt.show()

# %%
np.mean(df["popularity"])
# Out:
# np.float64(64.8509839375)

# %%
np.median(df["popularity"])
# Out:
# np.float64(36.1875)

# %%
np.min(df["popularity"])
# Out:
# 2.323

# %%
np.max(df["popularity"])
# Out:
# 6421.923

# %%
np.std(df["popularity"])
# Out:
# 139.38293346486154

# %%
np.percentile(df["popularity"], [25, 50, 75])
# Out:
# array([24.87475, 36.1875 , 62.1875 ])

# %%
df[["popularity", "vote_count"]].corr()
# Out:
#             popularity  vote_count
# popularity    1.000000    0.145118
# vote_count    0.145118    1.000000

# %%
df["duration"].head(10)
# Out:
# 0    1 Seasons
# 1    1 Seasons
# 2    1 Seasons
# 3    1 Seasons
# 4    1 Seasons
# 5    1 Seasons
# 6    1 Seasons
# 7    1 Seasons
# 8    1 Seasons
# 9    1 Seasons
# Name: duration, dtype: object

# %%
df["duration"].value_counts().head(10)
# Out:
# duration
# 1 Seasons    16000
# Name: count, dtype: int64

# %%
df["duration_number"] = df["duration"].str.extract(r"(\d+)").astype(float)

# %%
df["duration_number"].describe()
# Out:
# count    16000.0
# mean         1.0
# std          0.0
# min          1.0
# 25%          1.0
# 50%          1.0
# 75%          1.0
# max          1.0
# Name: duration_number, dtype: float64

# %%
df["duration_number"].value_counts().head(10)
# Out:
# duration_number
# 1.0    16000
# Name: count, dtype: int64

# %%
top_duration = df["duration_number"].value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(
    x=top_duration.index,
    y=top_duration.values
)
plt.title("Most Common Number of Seasons")
plt.xlabel("Number of Seasons")
plt.ylabel("Number of TV Shows")
plt.show()

# %%
year_counts = df["release_year"].value_counts().sort_index()
plt.figure(figsize=(12,5))
sns.lineplot(x=year_counts.index, y=year_counts.values)
plt.title("TV Shows Released by Year")
plt.xlabel("Release Year")
plt.ylabel("Number of TV Shows")
plt.show()

# %%
top_countries = country_counts.head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title("Top 10 Countries Producing TV Shows")
plt.xlabel("Number of TV Shows")
plt.ylabel("Country")
plt.show()

# %%
top_languages = language_counts.head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_languages.values, y=top_languages.index)
plt.title("Top 10 Languages of TV Shows")
plt.xlabel("Number of TV Shows")
plt.ylabel("Language")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=rating_counts.index, y=rating_counts.values)
plt.title("TV Shows by Rating")
plt.xlabel("Rating")
plt.ylabel("Number of TV Shows")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    x="vote_count",
    y="popularity",
    data=df
)
plt.title("Popularity vs Vote Count")
plt.xlabel("Vote Count")
plt.ylabel("Popularity")
plt.show()

# %%
df.loc[df["popularity"].idxmax(), ["title", "popularity"]]
# Out:
# title         The Late Show with Stephen Colbert
# popularity                              6421.923
# Name: 5000, dtype: object

# %%
df.loc[df["vote_count"].idxmax(), ["title", "vote_count"]]
# Out:
# title         Game of Thrones
# vote_count              24664
# Name: 1001, dtype: object

# %%
df["rating"].value_counts().head(1)
# Out:
# rating
# 0.0    3673
# Name: count, dtype: int64

# %%
language_counts.head(1)
# Out:
# language
# en    4437
# Name: count, dtype: int64

# %%
country_counts.head(1)
# Out:
# country_list
# Kana Hanazawa    72
# Name: count, dtype: int64

# %%
df["duration_number"].value_counts().head(1)
# Out:
# duration_number
# 1.0    16000
# Name: count, dtype: int64

# %%
df["release_year"].max()
# Out:
# 2025

# %%
df["release_year"].min()
# Out:
# 2010
